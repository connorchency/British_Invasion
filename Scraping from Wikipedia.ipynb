# %%
from bs4 import BeautifulSoup
import urllib, re

# %%
first = urllib.urlopen('https://en.wikipedia.org/wiki/List_of_British_Invasion_artists')

# %%
soup = BeautifulSoup(first, "lxml")

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of British Invasion artists - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
soup.find_all("div", class_="mw-content-ltr")
# Out:
# [<div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><p>The following is a list of bands and artists that were involved with the <a href="/wiki/British_Invasion" title="British Invasion">British Invasion</a> music phenomenon that occurred between 1964 and 1966 in the United States. (Artists shown in boldface are <a href="/wiki/Rock_and_Roll_Hall_of_Fame" title="Rock and Roll Hall of Fame">Rock and Roll Hall of Fame</a> inductees.)</p>\n<ul>\n<li><b><a href="/wiki/The_Animals" title="The Animals">The Animals</a></b><sup class="reference" id="cite_ref-FOOTNOTEGilliland1969show_29.2C_track_4.3B_show_49.2C_track_1_1-0"><a href="#cite_note-FOOTNOTEGilliland1969show_29.2C_track_4.3B_show_49.2C_track_1-1">[1]</a></sup><sup class="reference" id="cite_ref-MusicHound_2-0"><a href="#cite_note-MusicHound-2">[2]</a></sup></li>\n<li><b><a href="/wiki/The_Beatles" title="The Beatles">The Beatles</a></b><sup class="reference" id="cite_ref-FOOTNOTEGilliland1969shows_27-28_3-0"><a hre
# ...

# %%
print soup.find("div", { "class":"mw-content-ltr"}).prettify()
# Out:
# <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#  <p>
#   The following is a list of bands and artists that were involved with the
#   <a href="/wiki/British_Invasion" title="British Invasion">
#    British Invasion
#   </a>
#   music phenomenon that occurred between 1964 and 1966 in the United States. (Artists shown in boldface are
#   <a href="/wiki/Rock_and_Roll_Hall_of_Fame" title="Rock and Roll Hall of Fame">
#    Rock and Roll Hall of Fame
#   </a>
#   inductees.)
#  </p>
#  <ul>
#   <li>
#    <b>
#     <a href="/wiki/The_Animals" title="The Animals">
#      The Animals
#     </a>
#    </b>
#    <sup class="reference" id="cite_ref-FOOTNOTEGilliland1969show_29.2C_track_4.3B_show_49.2C_track_1_1-0">
#     <a href="#cite_note-FOOTNOTEGilliland1969show_29.2C_track_4.3B_show_49.2C_track_1-1">
#      [1]
#     </a>
#    </sup>
#    <sup class="reference" id="cite_ref-MusicHound_2-0">
#     <a href="#cite_note-MusicHound-2">
#      [2]
#     </a>
#    </sup>
# ...
